# %%
import pandas as pd
import os,sys

# %%
currentPath = os.getcwd()
ProcessedDataPath = currentPath + '/../data/processed'

# %%
crsp = pd.read_csv(ProcessedDataPath+'/dataset.csv', index_col=0)

# %%
crsp.shape[0] - crsp.dropna().shape[0]
# Out:
# 7

# %%
crsp
# Out:
#       permno  yyyymm         ret       prc  siccd_1310.0  siccd_3740.0  \
# 0    10000.0  198602  -26.244287 -3.250000           0.0           0.0
# 1    10000.0  198603   35.938461 -4.437500           0.0           0.0
# 2    10000.0  198604  -10.379155 -4.000000           0.0           0.0
# 3    10000.0  198605  -22.755625 -3.109375           0.0           0.0
# 4    10000.0  198606   -1.022513 -3.093750           0.0           0.0
# ..       ...     ...         ...       ...           ...           ...
# 974  10006.0  193203  -16.289032  6.500000           0.0           1.0
# 975  10006.0  193204  -15.494616  5.500000           0.0           1.0
# 976  10006.0  193205  -27.332728  4.000000           0.0           1.0
# 977  10006.0  193206   -3.145000  3.875000           0.0           1.0
# 978  10006.0  193207  116.099029  8.375000           0.0           1.0
#
#      siccd_3990.0  siccd_4920.0  siccd_4925.0  siccd_6020.0  ...    VolMkt  \
# ...
