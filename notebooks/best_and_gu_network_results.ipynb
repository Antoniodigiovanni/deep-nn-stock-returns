# %%
import sys
from pathlib import Path

# Add root folder to Python path (to import modules)
notebook_dir = Path().absolute()
project_root = notebook_dir.parent
sys.path.append(str(project_root))

# %%
import warnings
import pandas as pd
import src.models.neural_net.metric as metric
from src.portfolios.portfolio_new import Portfolio
import torch
import torchmetrics
from os import listdir
from os.path import isfile, join
import numpy as np
# Out:
# Device: cpu
# Epochs: 100
# Random seed set at: 21

# %% [markdown]
# # Gu et al. 2020

# %% [markdown]
# ## All networks from Grid search - Gu et al. 2020

# %%
gupath = '/home/ge65cuw/thesis/saved/results_old/NN3Ensemble/predicted_returns/'
gu_files_list = [f for f in listdir(gupath) if isfile(join(gupath, f))]

df_columns = columns=[
        'trial_id',
        'oosSpearman',
        'MDA', 
        'Turnover_long_VW', 
        'Turnover_short_VW', 
        'Turnover_long-short_VW', 
        'Max1MLoss_VW',
        'MaxDD_VW', 
        'Avg_ret_VW', 
        'Std_VW', 
        'Sharpe_ratio_VW', 
        'FF5_Mom_STRev_alpha_VW',
        'alpha_t-stat_VW',
        'regression_R2_VW', 
        'regression_Information_ratio_VW',
        'Turnover_long_EW', 
        'Turnover_short_EW', 
        'Turnover_long-short_EW', 
        'Max1MLoss_EW',
        'MaxDD_EW', 
        'Avg_ret_EW', 
        'Std_EW', 
        'Sharpe_ratio_EW', 
        'FF5_Mom_STRev_alpha_EW',
        'alpha_t-stat_EW', 
        'regression_R2_EW', 
        'regression_Information_ratio_EW']

import warnings
results_df = pd.DataFrame(columns=df_columns)
i=0
for file in gu_files_list:
        i+=1
        trial_id = file.split('_')[0] 
        results_dict = {}
        df = pd.read_csv(gupath + file, index_col=0)
        for column in df_columns:
                results_dict[column] = np.nan
        
        results_dict['trial_id'] = trial_id
        with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                results_dict['oosSpearman'] = metric.calc_spearman(torch.tensor(df['predicted_ret']), torch.tensor(df['ret'])).item()

        results_dict['MDA'] = metric.mean_directional_accuracy(df['predicted_ret'], df['ret'])
        try:
                portfolioVW = Portfolio(df, weighting='VW', verbose = 0)
                results_dict['Turnover_long_VW'] = portfolioVW.turnover['long']
                results_dict['Turnover_short_VW'] = portfolioVW.turnover['short']
                results_dict['Turnover_long-short_VW'] = portfolioVW.turnover['long-short']
                results_dict['Max1MLoss_VW'] = portfolioVW.max1MLoss_long_short
                results_dict['MaxDD_VW'] = portfolioVW.maxDD_long_short
                results_dict['Avg_ret_VW'] = portfolioVW.average_long_short_ret
                results_dict['Std_VW'] = portfolioVW.std_dev_long_short
                results_dict['Sharpe_ratio_VW'] = portfolioVW.long_short_sharpe_ratio
                results_dict['FF5_Mom_STRev_alpha_VW'] = portfolioVW.alpha
                results_dict['alpha_t-stat_VW'] = portfolioVW.t_value_alpha
                results_dict['regression_R2_VW'] = portfolioVW.regression_rsquared
                results_dict['regression_Information_ratio_VW'] = portfolioVW.information_ratio_regression
        except Exception as e:
                print('Error in Value Weighted Portfolio')
                print(e)
        #print('EW portfolio')
        try:
                portfolioEW = Portfolio(df, weighting='EW', verbose = 0)
                results_dict['Turnover_long_EW'] = portfolioEW.turnover['long']
                results_dict['Turnover_short_EW'] = portfolioEW.turnover['short']
                results_dict['Turnover_long-short_EW'] = portfolioEW.turnover['long-short']
                results_dict['Max1MLoss_EW'] = portfolioEW.max1MLoss_long_short
                results_dict['MaxDD_EW'] = portfolioEW.maxDD_long_short
                results_dict['Avg_ret_EW'] = portfolioEW.average_long_short_ret
                results_dict['Std_EW'] = portfolioEW.std_dev_long_short
                results_dict['Sharpe_ratio_EW'] = portfolioEW.long_short_sharpe_ratio
                results_dict['FF5_Mom_STRev_alpha_EW'] = portfolioEW.alpha
                results_dict['alpha_t-stat_EW'] = portfolioEW.t_value_alpha
                results_dict['regression_R2_EW'] = portfolioEW.regression_rsquared
                results_dict['regression_Information_ratio_EW'] = portfolioEW.information_ratio_regression
        except Exception as e:
                print('Error with Equal Weighted Portfolio')
                print(e)
        print(f'Trial no.{i} [of {len(gu_files_list)}] completed')     
        results = pd.DataFrame(results_dict, index=[0])
        results_df = pd.concat([results_df, results], ignore_index=True)

results_df.to_csv('/home/ge65cuw/thesis/saved/final_results/gu_net_grid_search_results.csv')
results_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb Cell 5 in <cell line: 36>()
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2254554d5f536572766572227d/home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=44'>45</a> with warnings.catch_warnings():
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2254554d5f536572766572227d/home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=45'>46</a>         warnings.simplefilter("ignore")
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2254554d5f536572766572227d/home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=46'>47</a>         results_dict['oosSpearman'] = metric.calc_spearman(torch.tensor(df['predicted_ret']), torch.tensor(df['ret'])).item()
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2254554d5f536572766572227d/home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=48'>49</a> results_dict['MDA'] = metric.mean_directional_accuracy(df['predicted_ret'], df['ret'])
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2254554d5f536572766572227d/home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=49'>50</a> try:
#
# File ~/thesis/src/models/neural_net/metric.py:154, in calc_spearman(preds, target)
#     151 from torchmetrics import SpearmanCorrCoef
#     152 spearman = SpearmanCorrCoef()
# --> 154 return spearman(preds, target)
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/torchmetrics/metric.py:237, in Metric.forward(self, *args, **kwargs)
#     235     self._forward_cache = self._forward_full_state_update(*args, **kwargs)
#     236 else:
# --> 237     self._forward_cache = self._forward_reduce_state_update(*args, **kwargs)
#     239 return self._forward_cache
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/torchmetrics/metric.py:302, in Metric._forward_reduce_state_update(self, *args, **kwargs)
#     300 # calculate batch state and compute batch value
#     301 self.update(*args, **kwargs)
# --> 302 batch_val = self.compute()
#     304 # reduce batch and global state
#     305 self._update_count = _update_count + 1
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/torchmetrics/metric.py:523, in Metric._wrap_compute.<locals>.wrapped_func(*args, **kwargs)
#     515 # compute relies on the sync context manager to gather the states across processes and apply reduction
#     516 # if synchronization happened, the current rank accumulated states will be restored to keep
#     517 # accumulation going if ``should_unsync=True``,
#     518 with self.sync_context(
#     519     dist_sync_fn=self.dist_sync_fn,  # type: ignore
#     520     should_sync=self._to_sync,
#     521     should_unsync=self._should_unsync,
#     522 ):
# --> 523     value = compute(*args, **kwargs)
#     524     self._computed = _squeeze_if_scalar(value)
#     526 return self._computed
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/torchmetrics/regression/spearman.py:81, in SpearmanCorrCoef.compute(self)
#      79 preds = dim_zero_cat(self.preds)
#      80 target = dim_zero_cat(self.target)
# ---> 81 return _spearman_corrcoef_compute(preds, target)
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/torchmetrics/functional/regression/spearman.py:95, in _spearman_corrcoef_compute(preds, target, eps)
#      79 """Computes Spearman Correlation Coefficient.
#      80
#      81 Args:
#    (...)
#      91     tensor(1.0000)
#      92 """
#      94 preds = _rank_data(preds)
# ---> 95 target = _rank_data(target)
#      97 preds_diff = preds - preds.mean()
#      98 target_diff = target - target.mean()
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/torchmetrics/functional/regression/spearman.py:51, in _rank_data(data)
#      49 for r in repeats:
#      50     condition = data == r
# ---> 51     rank[condition] = rank[condition].mean()
#      52 return rank
#
# KeyboardInterrupt:

# %% [markdown]
# ## Ensemble - Gu et al. 2020

# %%
results_df = pd.DataFrame()
results_dict = {}
df = pd.read_csv('/home/ge65cuw/thesis/saved/final_results/ensembleGu.csv', index_col=0)

with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        results_dict['oosSpearman'] = metric.calc_spearman(torch.tensor(df['predicted_ret']), torch.tensor(df['ret'])).item()

results_dict['MDA'] = metric.mean_directional_accuracy(df['predicted_ret'], df['ret'])
try:
        portfolioVW = Portfolio(df, weighting='VW', verbose = 1)
        results_dict['Turnover_long_VW'] = portfolioVW.turnover['long']
        results_dict['Turnover_short_VW'] = portfolioVW.turnover['short']
        results_dict['Turnover_long-short_VW'] = portfolioVW.turnover['long-short']
        results_dict['Max1MLoss_VW'] = portfolioVW.max1MLoss_long_short
        results_dict['MaxDD_VW'] = portfolioVW.maxDD_long_short
        results_dict['Avg_ret_VW'] = portfolioVW.average_long_short_ret
        results_dict['Std_VW'] = portfolioVW.std_dev_long_short
        results_dict['Sharpe_ratio_VW'] = portfolioVW.long_short_sharpe_ratio
        results_dict['FF5_Mom_STRev_alpha_VW'] = portfolioVW.alpha
        results_dict['alpha_t-stat_VW'] = portfolioVW.t_value_alpha
        results_dict['regression_R2_VW'] = portfolioVW.regression_rsquared
        results_dict['regression_Information_ratio_VW'] = portfolioVW.information_ratio_regression
except Exception as e:
        print('Error in Value Weighted Portfolio')
        print(e)
#print('EW portfolio')
try:
        portfolioEW = Portfolio(df, weighting='EW', verbose = 0)
        results_dict['Turnover_long_EW'] = portfolioEW.turnover['long']
        results_dict['Turnover_short_EW'] = portfolioEW.turnover['short']
        results_dict['Turnover_long-short_EW'] = portfolioEW.turnover['long-short']
        results_dict['Max1MLoss_EW'] = portfolioEW.max1MLoss_long_short
        results_dict['MaxDD_EW'] = portfolioEW.maxDD_long_short
        results_dict['Avg_ret_EW'] = portfolioEW.average_long_short_ret
        results_dict['Std_EW'] = portfolioEW.std_dev_long_short
        results_dict['Sharpe_ratio_EW'] = portfolioEW.long_short_sharpe_ratio
        results_dict['FF5_Mom_STRev_alpha_EW'] = portfolioEW.alpha
        results_dict['alpha_t-stat_EW'] = portfolioEW.t_value_alpha
        results_dict['regression_R2_EW'] = portfolioEW.regression_rsquared
        results_dict['regression_Information_ratio_EW'] = portfolioEW.information_ratio_regression
except Exception as e:
        print('Error with Equal Weighted Portfolio')
        print(e)

results = pd.DataFrame(results_dict, index=[0])
pd.set_option('display.max_columns', None)
results
# Out:
# Loading the dataset...
# Features stats:
# Mean: -0.01	Std: 0.29	Median: -0.02
# IR & alpha calculation...
# Params
# const     1.585319
# Mkt-RF   -0.042643
# SMB      -0.456151
# HML       0.284871
# RMW       0.433332
# CMA       0.338306
# Mom       0.134050
# ST_Rev   -0.125761
# dtype: float64
# tValues
# const     6.466020
# Mkt-RF   -0.664069
# SMB      -5.523790
# HML       2.765142
# RMW       4.010977
# CMA       2.253171
# Mom       2.532449
# ST_Rev   -1.865450
# dtype: float64
# Linear Regression summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    l-s   R-squared:                       0.409
# Model:                            OLS   Adj. R-squared:                  0.395
# Method:                 Least Squares   F-statistic:                     28.51
# Date:                Fri, 18 Nov 2022   Prob (F-statistic):           1.01e-29
# Time:                        09:48:44   Log-Likelihood:                -816.21
# No. Observations:                 296   AIC:                             1648.
# Df Residuals:                     288   BIC:                             1678.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5853      0.245      6.466      0.000       1.103       2.068
# Mkt-RF        -0.0426      0.064     -0.664      0.507      -0.169       0.084
# SMB           -0.4562      0.083     -5.524      0.000      -0.619      -0.294
# HML            0.2849      0.103      2.765      0.006       0.082       0.488
# RMW            0.4333      0.108      4.011      0.000       0.221       0.646
# CMA            0.3383      0.150      2.253      0.025       0.043       0.634
# Mom            0.1340      0.053      2.532      0.012       0.030       0.238
# ST_Rev        -0.1258      0.067     -1.865      0.063      -0.258       0.007
# ==============================================================================
# Omnibus:                       18.790   Durbin-Watson:                   1.779
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.166
# Skew:                           0.331   Prob(JB):                     8.50e-09
# Kurtosis:                       4.605   Cond. No.                         6.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Linear Regression R-squared:
# 0.4092886249533978
# Informatio Ratio based on FF5FM+Mom regression: 0.36 (long-short)
# Average return:
# 	Long: 0.55%	Long-short: 1.85%
# T is 296
# Annualized returns:
# 	Long: 6.11%	Long-short:22.94%
# Annualized Market Returns 0.12%
# Standard deviation on returns:
# 	Long: 3.24	Long-short:4.96
# Alpha over market:	Long:-0.07%	Long-short:0.07%
# Average Return per decile
# decile
# 1     -1.307217
# 2     -0.738095
# 3     -0.276804
# 4     -0.222573
# 5     -0.062363
# 6      0.224061
# 7      0.236757
# 8      0.290170
# 9      0.316454
# 10     0.547588
# l-s    1.854805
# dtype: float64
#    oosSpearman       MDA  Turnover_long_VW  Turnover_short_VW  \
# 0     0.076688  0.524872        151.315893         124.287184
#
#    Turnover_long-short_VW  Max1MLoss_VW  MaxDD_VW  Avg_ret_VW   Std_VW  \
# 0              275.603077     13.454363  0.400844    1.854805  4.96168
#
#    Sharpe_ratio_VW  FF5_Mom_STRev_alpha_VW  alpha_t-stat_VW  regression_R2_VW  \
# 0         0.373826                1.585319          6.46602          0.409289
#
#    regression_Information_ratio_VW  Turnover_long_EW  Turnover_short_EW  \
# 0                         0.360337         22.317198          26.759792
#
#    Turnover_long-short_EW  Max1MLoss_EW  MaxDD_EW  Avg_ret_EW    Std_EW  \
# 0                49.07699      9.221077  0.111946     0.87637  2.007644
#
#    Sharpe_ratio_EW  FF5_Mom_STRev_alpha_EW  alpha_t-stat_EW  regression_R2_EW  \
# 0         0.436517                0.710001         8.739815          0.603892
#
#    regression_Information_ratio_EW
# 0                         0.487051

# %% [markdown]
# # Linear benchmark

# %%
linearPredictedRet = '/home/ge65cuw/thesis/saved/final_results/linear/predicted_ret.csv'

# %%
df = pd.read_csv(linearPredictedRet, index_col=0)
df = df.loc[df.yyyymm >= 200001]
df2 = pd.read_csv('/home/ge65cuw/thesis/saved/final_results/ensembleGu.csv', index_col=0)
print(df.shape, df2.shape)
# Out:
# (1670935, 4) (473018, 4)

# %%
import torch
t1 = torch.tensor(df['predicted_ret'].to_numpy())
t2 = torch.tensor(df['ret'].to_numpy())
spearman = metric.calc_spearman(t1,t2).item()
spearman
# Out:
# /home/ge65cuw/anaconda3/envs/thesis/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `SpearmanCorrcoef` will save all targets and predictions in the buffer. For large datasets, this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# 0.05678696720163356

# %%
MDA = metric.mean_directional_accuracy(df['predicted_ret'], df['ret'])
MDA
# Out:
# 0.5190160000239387

# %%
results_df = pd.DataFrame()
results_dict = {}
df = pd.read_csv(linearPredictedRet, index_col=0)

with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        results_dict['oosSpearman'] = metric.calc_spearman(torch.tensor(df['predicted_ret']), torch.tensor(df['ret'])).item()

results_dict['MDA'] = metric.mean_directional_accuracy(df['predicted_ret'], df['ret'])
try:
        portfolioVW = Portfolio(df, weighting='VW', verbose = 0)
        results_dict['Turnover_long_VW'] = portfolioVW.turnover['long']
        results_dict['Turnover_short_VW'] = portfolioVW.turnover['short']
        results_dict['Turnover_long-short_VW'] = portfolioVW.turnover['long-short']
        results_dict['Max1MLoss_VW'] = portfolioVW.max1MLoss_long_short
        results_dict['MaxDD_VW'] = portfolioVW.maxDD_long_short
        results_dict['Avg_ret_VW'] = portfolioVW.average_long_short_ret
        results_dict['Std_VW'] = portfolioVW.std_dev_long_short
        results_dict['Sharpe_ratio_VW'] = portfolioVW.long_short_sharpe_ratio
        results_dict['FF5_Mom_STRev_alpha_VW'] = portfolioVW.alpha
        results_dict['alpha_t-stat_VW'] = portfolioVW.t_value_alpha
        results_dict['regression_R2_VW'] = portfolioVW.regression_rsquared
        results_dict['regression_Information_ratio_VW'] = portfolioVW.information_ratio_regression
except Exception as e:
        print('Error in Value Weighted Portfolio')
        print(e)
#print('EW portfolio')
try:
        portfolioEW = Portfolio(df, weighting='EW', verbose = 0)
        results_dict['Turnover_long_EW'] = portfolioEW.turnover['long']
        results_dict['Turnover_short_EW'] = portfolioEW.turnover['short']
        results_dict['Turnover_long-short_EW'] = portfolioEW.turnover['long-short']
        results_dict['Max1MLoss_EW'] = portfolioEW.max1MLoss_long_short
        results_dict['MaxDD_EW'] = portfolioEW.maxDD_long_short
        results_dict['Avg_ret_EW'] = portfolioEW.average_long_short_ret
        results_dict['Std_EW'] = portfolioEW.std_dev_long_short
        results_dict['Sharpe_ratio_EW'] = portfolioEW.long_short_sharpe_ratio
        results_dict['FF5_Mom_STRev_alpha_EW'] = portfolioEW.alpha
        results_dict['alpha_t-stat_EW'] = portfolioEW.t_value_alpha
        results_dict['regression_R2_EW'] = portfolioEW.regression_rsquared
        results_dict['regression_Information_ratio_EW'] = portfolioEW.information_ratio_regression
except Exception as e:
        print('Error with Equal Weighted Portfolio')
        print(e)

results = pd.DataFrame(results_dict, index=[0])
pd.set_option('display.max_columns', None)
results
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb Cell 9 in <cell line: 5>()
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2254554d5f536572766572227d/home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> with warnings.catch_warnings():
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2254554d5f536572766572227d/home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>         warnings.simplefilter("ignore")
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2254554d5f536572766572227d/home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>         results_dict['oosSpearman'] = metric.calc_spearman(torch.tensor(df['predicted_ret']), torch.tensor(df['ret'])).item()
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2254554d5f536572766572227d/home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> results_dict['MDA'] = metric.mean_directional_accuracy(df['predicted_ret'], df['ret'])
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2254554d5f536572766572227d/home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> # try:
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2254554d5f536572766572227d/home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> #         portfolioVW = Portfolio(df, weighting='VW', verbose = 0)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2254554d5f536572766572227d/home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> #         results_dict['Turnover_long_VW'] = portfolioVW.turnover['long']
#    (...)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2254554d5f536572766572227d/home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=42'>43</a> #         print('Error with Equal Weighted Portfolio')
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2254554d5f536572766572227d/home/ge65cuw/thesis/src/best_and_gu_network_results.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=43'>44</a> #         print(e)
#
# File ~/thesis/src/models/neural_net/metric.py:154, in calc_spearman(preds, target)
#     151 from torchmetrics import SpearmanCorrCoef
#     152 spearman = SpearmanCorrCoef()
# --> 154 return spearman(preds, target)
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/torchmetrics/metric.py:237, in Metric.forward(self, *args, **kwargs)
#     235     self._forward_cache = self._forward_full_state_update(*args, **kwargs)
#     236 else:
# --> 237     self._forward_cache = self._forward_reduce_state_update(*args, **kwargs)
#     239 return self._forward_cache
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/torchmetrics/metric.py:302, in Metric._forward_reduce_state_update(self, *args, **kwargs)
#     300 # calculate batch state and compute batch value
#     301 self.update(*args, **kwargs)
# --> 302 batch_val = self.compute()
#     304 # reduce batch and global state
#     305 self._update_count = _update_count + 1
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/torchmetrics/metric.py:523, in Metric._wrap_compute.<locals>.wrapped_func(*args, **kwargs)
#     515 # compute relies on the sync context manager to gather the states across processes and apply reduction
#     516 # if synchronization happened, the current rank accumulated states will be restored to keep
#     517 # accumulation going if ``should_unsync=True``,
#     518 with self.sync_context(
#     519     dist_sync_fn=self.dist_sync_fn,  # type: ignore
#     520     should_sync=self._to_sync,
#     521     should_unsync=self._should_unsync,
#     522 ):
# --> 523     value = compute(*args, **kwargs)
#     524     self._computed = _squeeze_if_scalar(value)
#     526 return self._computed
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/torchmetrics/regression/spearman.py:81, in SpearmanCorrCoef.compute(self)
#      79 preds = dim_zero_cat(self.preds)
#      80 target = dim_zero_cat(self.target)
# ---> 81 return _spearman_corrcoef_compute(preds, target)
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/torchmetrics/functional/regression/spearman.py:95, in _spearman_corrcoef_compute(preds, target, eps)
#      79 """Computes Spearman Correlation Coefficient.
#      80
#      81 Args:
#    (...)
#      91     tensor(1.0000)
#      92 """
#      94 preds = _rank_data(preds)
# ---> 95 target = _rank_data(target)
#      97 preds_diff = preds - preds.mean()
#      98 target_diff = target - target.mean()
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/torchmetrics/functional/regression/spearman.py:51, in _rank_data(data)
#      49 for r in repeats:
#      50     condition = data == r
# ---> 51     rank[condition] = rank[condition].mean()
#      52 return rank
#
# KeyboardInterrupt:

# %% [markdown]
# # All results from NN3 Grid Search

# %%
nn3path = '/home/ge65cuw/thesis/saved/results_old/NN3Ensemble/predicted_returns/'
nn3_files_list = [f for f in listdir(nn3path) if isfile(join(nn3path, f))]

# %%
df_columns = columns=[
        'trial_id',
        'oosSpearman',
        'MDA', 
        'Turnover_long_VW', 
        'Turnover_short_VW', 
        'Turnover_long-short_VW', 
        'Max1MLoss_VW',
        'MaxDD_VW', 
        'Avg_ret_VW', 
        'Std_VW', 
        'Sharpe_ratio_VW', 
        'FF5_Mom_STRev_alpha_VW',
        'alpha_t-stat_VW',
        'regression_R2_VW', 
        'regression_Information_ratio_VW',
        'Turnover_long_EW', 
        'Turnover_short_EW', 
        'Turnover_long-short_EW', 
        'Max1MLoss_EW',
        'MaxDD_EW', 
        'Avg_ret_EW', 
        'Std_EW', 
        'Sharpe_ratio_EW', 
        'FF5_Mom_STRev_alpha_EW',
        'alpha_t-stat_EW', 
        'regression_R2_EW', 
        'regression_Information_ratio_EW']

import warnings
results_df = pd.DataFrame(columns=df_columns)
i=0
for file in gu_files_list:
        i+=1
        trial_id = file.split('_')[0] 
        results_dict = {}
        df = pd.read_csv(gupath + file, index_col=0)
        for column in df_columns:
                results_dict[column] = np.nan
        
        results_dict['trial_id'] = trial_id
        with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                results_dict['oosSpearman'] = metric.calc_spearman(torch.tensor(df['predicted_ret']), torch.tensor(df['ret'])).item()

        results_dict['MDA'] = metric.mean_directional_accuracy(df['predicted_ret'], df['ret'])
        try:
                portfolioVW = Portfolio(df, weighting='VW', verbose = 0)
                results_dict['Turnover_long_VW'] = portfolioVW.turnover['long']
                results_dict['Turnover_short_VW'] = portfolioVW.turnover['short']
                results_dict['Turnover_long-short_VW'] = portfolioVW.turnover['long-short']
                results_dict['Max1MLoss_VW'] = portfolioVW.max1MLoss_long_short
                results_dict['MaxDD_VW'] = portfolioVW.maxDD_long_short
                results_dict['Avg_ret_VW'] = portfolioVW.average_long_short_ret
                results_dict['Std_VW'] = portfolioVW.std_dev_long_short
                results_dict['Sharpe_ratio_VW'] = portfolioVW.long_short_sharpe_ratio
                results_dict['FF5_Mom_STRev_alpha_VW'] = portfolioVW.alpha
                results_dict['alpha_t-stat_VW'] = portfolioVW.t_value_alpha
                results_dict['regression_R2_VW'] = portfolioVW.regression_rsquared
                results_dict['regression_Information_ratio_VW'] = portfolioVW.information_ratio_regression
        except Exception as e:
                print('Error in Value Weighted Portfolio')
                print(e)
        #print('EW portfolio')
        try:
                portfolioEW = Portfolio(df, weighting='EW', verbose = 0)
                results_dict['Turnover_long_EW'] = portfolioEW.turnover['long']
                results_dict['Turnover_short_EW'] = portfolioEW.turnover['short']
                results_dict['Turnover_long-short_EW'] = portfolioEW.turnover['long-short']
                results_dict['Max1MLoss_EW'] = portfolioEW.max1MLoss_long_short
                results_dict['MaxDD_EW'] = portfolioEW.maxDD_long_short
                results_dict['Avg_ret_EW'] = portfolioEW.average_long_short_ret
                results_dict['Std_EW'] = portfolioEW.std_dev_long_short
                results_dict['Sharpe_ratio_EW'] = portfolioEW.long_short_sharpe_ratio
                results_dict['FF5_Mom_STRev_alpha_EW'] = portfolioEW.alpha
                results_dict['alpha_t-stat_EW'] = portfolioEW.t_value_alpha
                results_dict['regression_R2_EW'] = portfolioEW.regression_rsquared
                results_dict['regression_Information_ratio_EW'] = portfolioEW.information_ratio_regression
        except Exception as e:
                print('Error with Equal Weighted Portfolio')
                print(e)
        print(f'Trial no.{i} [of {len(gu_files_list)}] completed')     
        results = pd.DataFrame(results_dict, index=[0])
        results_df = pd.concat([results_df, results], ignore_index=True)

results_df.to_csv('/home/ge65cuw/thesis/saved/final_results/best_net_grid_search_results.csv')
results_df
# Out:
# Remove MaxDD printing and implement logic to not save networks which fail at creating portfolios
# Trial no.1 [of 10] completed
# Trial no.2 [of 10] completed
# Trial no.3 [of 10] completed
# Trial no.4 [of 10] completed
# Trial no.5 [of 10] completed
# Trial no.6 [of 10] completed
# Trial no.7 [of 10] completed
# Trial no.8 [of 10] completed
# Trial no.9 [of 10] completed
# Trial no.10 [of 10] completed

# %% [markdown]
# ## Ensemble results

# %%
results_df = pd.DataFrame()
results_dict = {}
df = pd.read_csv('/home/ge65cuw/thesis/saved/final_results/ensembleNN3.csv', index_col=0)

with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        results_dict['oosSpearman'] = metric.calc_spearman(torch.tensor(df['predicted_ret']), torch.tensor(df['ret'])).item()

results_dict['MDA'] = metric.mean_directional_accuracy(df['predicted_ret'], df['ret'])
try:
        portfolioVW = Portfolio(df, weighting='VW', verbose = 1)
        results_dict['Turnover_long_VW'] = portfolioVW.turnover['long']
        results_dict['Turnover_short_VW'] = portfolioVW.turnover['short']
        results_dict['Turnover_long-short_VW'] = portfolioVW.turnover['long-short']
        results_dict['Max1MLoss_VW'] = portfolioVW.max1MLoss_long_short
        results_dict['MaxDD_VW'] = portfolioVW.maxDD_long_short
        results_dict['Avg_ret_VW'] = portfolioVW.average_long_short_ret
        results_dict['Std_VW'] = portfolioVW.std_dev_long_short
        results_dict['Sharpe_ratio_VW'] = portfolioVW.long_short_sharpe_ratio
        results_dict['FF5_Mom_STRev_alpha_VW'] = portfolioVW.alpha
        results_dict['alpha_t-stat_VW'] = portfolioVW.t_value_alpha
        results_dict['regression_R2_VW'] = portfolioVW.regression_rsquared
        results_dict['regression_Information_ratio_VW'] = portfolioVW.information_ratio_regression
except Exception as e:
        print('Error in Value Weighted Portfolio')
        print(e)
#print('EW portfolio')
try:
        portfolioEW = Portfolio(df, weighting='EW', verbose = 0)
        results_dict['Turnover_long_EW'] = portfolioEW.turnover['long']
        results_dict['Turnover_short_EW'] = portfolioEW.turnover['short']
        results_dict['Turnover_long-short_EW'] = portfolioEW.turnover['long-short']
        results_dict['Max1MLoss_EW'] = portfolioEW.max1MLoss_long_short
        results_dict['MaxDD_EW'] = portfolioEW.maxDD_long_short
        results_dict['Avg_ret_EW'] = portfolioEW.average_long_short_ret
        results_dict['Std_EW'] = portfolioEW.std_dev_long_short
        results_dict['Sharpe_ratio_EW'] = portfolioEW.long_short_sharpe_ratio
        results_dict['FF5_Mom_STRev_alpha_EW'] = portfolioEW.alpha
        results_dict['alpha_t-stat_EW'] = portfolioEW.t_value_alpha
        results_dict['regression_R2_EW'] = portfolioEW.regression_rsquared
        results_dict['regression_Information_ratio_EW'] = portfolioEW.information_ratio_regression
except Exception as e:
        print('Error with Equal Weighted Portfolio')
        print(e)

nn3_results = pd.DataFrame(results_dict, index=[0])
pd.set_option('display.max_columns', None)
nn3_results
# Out:
# Loading the dataset...
# Features stats:
# Mean: -0.01	Std: 0.29	Median: -0.02
# IR & alpha calculation...
# Params
# const     1.390458
# Mkt-RF   -0.045262
# SMB      -0.157068
# HML       0.346980
# RMW       0.138406
# CMA       0.260275
# Mom       0.018406
# ST_Rev   -0.006553
# dtype: float64
# tValues
# const     6.178562
# Mkt-RF   -0.767920
# SMB      -2.072170
# HML       3.669293
# RMW       1.395709
# CMA       1.888540
# Mom       0.378823
# ST_Rev   -0.105896
# dtype: float64
# Linear Regression summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    l-s   R-squared:                       0.228
# Model:                            OLS   Adj. R-squared:                  0.209
# Method:                 Least Squares   F-statistic:                     12.13
# Date:                Fri, 18 Nov 2022   Prob (F-statistic):           1.41e-13
# Time:                        09:56:12   Log-Likelihood:                -790.85
# No. Observations:                 296   AIC:                             1598.
# Df Residuals:                     288   BIC:                             1627.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.3905      0.225      6.179      0.000       0.948       1.833
# Mkt-RF        -0.0453      0.059     -0.768      0.443      -0.161       0.071
# SMB           -0.1571      0.076     -2.072      0.039      -0.306      -0.008
# HML            0.3470      0.095      3.669      0.000       0.161       0.533
# RMW            0.1384      0.099      1.396      0.164      -0.057       0.334
# CMA            0.2603      0.138      1.889      0.060      -0.011       0.532
# Mom            0.0184      0.049      0.379      0.705      -0.077       0.114
# ST_Rev        -0.0066      0.062     -0.106      0.916      -0.128       0.115
# ==============================================================================
# Omnibus:                       17.607   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.752
# Skew:                           0.511   Prob(JB):                     3.12e-05
# Kurtosis:                       3.800   Cond. No.                         6.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Linear Regression R-squared:
# 0.22766412946765058
# Informatio Ratio based on FF5FM+Mom regression: 0.34 (long-short)
# Average return:
# 	Long: 0.55%	Long-short: 1.51%
# T is 296
# Annualized returns:
# 	Long: 6.17%	Long-short:18.68%
# Annualized Market Returns 0.12%
# Standard deviation on returns:
# 	Long: 3.13	Long-short:3.98
# Alpha over market:	Long:-0.07%	Long-short:0.04%
# Average Return per decile
# decile
# 1     -0.965469
# 2     -0.630470
# 3     -0.204021
# 4     -0.011589
# 5      0.081676
# 6      0.145935
# 7      0.121335
# 8      0.402420
# 9      0.365397
# 10     0.548650
# l-s    1.514119
# dtype: float64
#    oosSpearman       MDA  Turnover_long_VW  Turnover_short_VW  \
# 0     0.071609  0.523587         143.23767         131.071197
#
#    Turnover_long-short_VW  Max1MLoss_VW  MaxDD_VW  Avg_ret_VW    Std_VW  \
# 0              274.308867      9.047608  0.475057    1.514119  3.982943
#
#    Sharpe_ratio_VW  FF5_Mom_STRev_alpha_VW  alpha_t-stat_VW  regression_R2_VW  \
# 0         0.380151                1.390458         6.178562          0.227664
#
#    regression_Information_ratio_VW  Turnover_long_EW  Turnover_short_EW  \
# 0                         0.344318          21.82325          25.251775
#
#    Turnover_long-short_EW  Max1MLoss_EW  MaxDD_EW  Avg_ret_EW    Std_EW  \
# 0               47.075025       9.27322  0.121359    0.908055  2.049344
#
#    Sharpe_ratio_EW  FF5_Mom_STRev_alpha_EW  alpha_t-stat_EW  regression_R2_EW  \
# 0         0.443095                0.734495          9.04262          0.619956
#
#    regression_Information_ratio_EW
# 0                         0.503926
